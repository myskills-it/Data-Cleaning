# %%
import pandas as pd

# %% [markdown]
# ### Load CSV Dataset into DataFrame

# %%
df=pd.read_csv("C:/Users/sheheryarsh/Desktop/JUPYTER-LAB/datasets/employees_data.csv")

# %%
print(df)
# Out:
#    Employee_ID              Name   Department   Hire_Date  Salary  \
# 0         E101        John Smith  Engineering  15/03/2021   85000
# 1         E102          Jane Doe    Marketing  10/22/2022   65000
# 2         E103       Mark Taylor        Sales   5/11/2023   72000
# 3         E104      Sarah Connor           HR   12/1/2024   55000
# 4         E105         David Lee  Engineering   1/15/2025   90000
# ..         ...               ...          ...         ...     ...
# 95        E196    Tristan Knight  Engineering  14/09/2024  112000
# 96        E197   Serenity Willis        Sales  18/02/2025   83000
# 97        E198      Ryder Weaver    Marketing   9/24/2021   74000
# 98        E199  Adeline Johnston        Legal  12/10/2022   96000
# 99        E200    Sawyer Osborne           IT  21/11/2023   89000
#
#                            Email
# 0         john.smith@company.com
# 1           jane.doe@company.com
# 2        mark.taylor@company.com
# 3       sarah.connor@company.com
# ...

# %% [markdown]
# ### Locate First Row

# %%
print(df.loc[0])
# Out:
# Employee_ID                      E101
# Name                       John Smith
# Department                Engineering
# Hire_Date                  15/03/2021
# Salary                          85000
# Email          john.smith@company.com
# Name: 0, dtype: str

# %% [markdown]
# ### Locate First Two Rows

# %%
df.loc[[0,1,2]]
# Out:
#   Employee_ID         Name   Department   Hire_Date Salary  \
# 0        E101   John Smith  Engineering  15/03/2021  85000
# 1        E102     Jane Doe    Marketing  10/22/2022  65000
# 2        E103  Mark Taylor        Sales   5/11/2023  72000
#
#                      Email
# 0   john.smith@company.com
# 1     jane.doe@company.com
# 2  mark.taylor@company.com

# %% [markdown]
# ### Display Entire Dataset

# %%
print(df.to_string())
# Out:
#    Employee_ID               Name   Department   Hire_Date     Salary                          Email
# 0         E101         John Smith  Engineering  15/03/2021      85000         john.smith@company.com
# 1         E102           Jane Doe    Marketing  10/22/2022      65000           jane.doe@company.com
# 2         E103        Mark Taylor        Sales   5/11/2023      72000        mark.taylor@company.com
# 3         E104       Sarah Connor           HR   12/1/2024      55000       sarah.connor@company.com
# 4         E105          David Lee  Engineering   1/15/2025      90000          david.lee@company.com
# 5         E101         John Smith  Engineering  15/03/2021      85000         john.smith@company.com
# 6         E107        Alice Brown      Finance  14/04/2022      95000                            NaN
# 7         E108       Robert Green   Operations         NaN      52000       robert.green@company.com
# ...

# %% [markdown]
# ## Analyzing DataFrame

# %% [markdown]
# #### Top first 5 Rows

# %%
df.head()
# Out:
#   Employee_ID          Name   Department   Hire_Date Salary  \
# 0        E101    John Smith  Engineering  15/03/2021  85000
# 1        E102      Jane Doe    Marketing  10/22/2022  65000
# 2        E103   Mark Taylor        Sales   5/11/2023  72000
# 3        E104  Sarah Connor           HR   12/1/2024  55000
# 4        E105     David Lee  Engineering   1/15/2025  90000
#
#                       Email
# 0    john.smith@company.com
# 1      jane.doe@company.com
# 2   mark.taylor@company.com
# 3  sarah.connor@company.com
# 4     david.lee@company.com

# %% [markdown]
# ### Display first 10 Rows

# %%
df.head(10)
# Out:
#   Employee_ID           Name   Department   Hire_Date     Salary  \
# 0        E101     John Smith  Engineering  15/03/2021      85000
# 1        E102       Jane Doe    Marketing  10/22/2022      65000
# 2        E103    Mark Taylor        Sales   5/11/2023      72000
# 3        E104   Sarah Connor           HR   12/1/2024      55000
# 4        E105      David Lee  Engineering   1/15/2025      90000
# 5        E101     John Smith  Engineering  15/03/2021      85000
# 6        E107    Alice Brown      Finance  14/04/2022      95000
# 7        E108   Robert Green   Operations         NaN      52000
# 8        E109    Emily White           IT   9/15/2023  seventy_k
# 9        E110  Michael Clark  Engineering  31/12/2021     110000
#
#                       Email
# 0    john.smith@company.com
# 1      jane.doe@company.com
# 2   mark.taylor@company.com
# 3  sarah.connor@company.com
# 4     david.lee@company.com
# 5    john.smith@company.com
# 6                       NaN
# ...

# %% [markdown]
# ### Display last 10 Rows

# %%
df.tail(10)
# Out:
#    Employee_ID              Name   Department   Hire_Date  Salary  \
# 90        E191  Josephine Hansen        Legal  26/03/2024   95000
# 91        E192  Lincoln Matthews           IT  10/25/2025   87000
# 92        E193     Eva Gutierrez      Finance  14/05/2021   98000
# 93        E194       Ian Simpson   Operations  23/06/2022   54000
# 94        E188      Brody Medina  Engineering  11/12/2021  110000
# 95        E196    Tristan Knight  Engineering  14/09/2024  112000
# 96        E197   Serenity Willis        Sales  18/02/2025   83000
# 97        E198      Ryder Weaver    Marketing   9/24/2021   74000
# 98        E199  Adeline Johnston        Legal  12/10/2022   96000
# 99        E200    Sawyer Osborne           IT  21/11/2023   89000
#
#                            Email
# 90  josephine.hansen@company.com
# 91  lincoln.matthews@company.com
# 92     eva.gutierrez@company.com
# 93       ian.simpson@company.com
# 94      brody.medina@company.com
# 95    tristan.knight@company.com
# ...

# %% [markdown]
# ### Print information about the dataframe

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  100 non-null    str
#  1   Name         100 non-null    str
#  2   Department   98 non-null     str
#  3   Hire_Date    99 non-null     str
#  4   Salary       100 non-null    str
#  5   Email        94 non-null     str
# dtypes: str(6)
# memory usage: 4.8 KB
# None

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Remove Empty Cells (rows:6, 7, 11, 17, 19, 27, 25, 69, 89)

# %%
df.dropna(inplace=True)

# %%
print(df.to_string())
# Out:
#    Employee_ID               Name   Department   Hire_Date     Salary                          Email
# 0         E101         John Smith  Engineering  15/03/2021      85000         john.smith@company.com
# 1         E102           Jane Doe    Marketing  10/22/2022      65000           jane.doe@company.com
# 2         E103        Mark Taylor        Sales   5/11/2023      72000        mark.taylor@company.com
# 3         E104       Sarah Connor           HR   12/1/2024      55000       sarah.connor@company.com
# 4         E105          David Lee  Engineering   1/15/2025      90000          david.lee@company.com
# 5         E101         John Smith  Engineering  15/03/2021      85000         john.smith@company.com
# 8         E109        Emily White           IT   9/15/2023  seventy_k        emily.white@company.com
# 9         E110      Michael Clark  Engineering  31/12/2021     110000            m.clark@company.com
# ...
